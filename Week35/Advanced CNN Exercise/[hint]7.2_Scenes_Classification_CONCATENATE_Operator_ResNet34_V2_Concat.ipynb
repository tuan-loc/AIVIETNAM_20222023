# %% [markdown]
# ## Download Data

# %%
# !pip install tensorflow==2.8.0

# %%
# !pip install -U --no-cache-dir gdown --pre
# !gdown --id 1hIA30U0onXAHyqeic-uuzJ-xbzt8J1EQ

# %%
# !unzip scenes_classification.zip

# %%
import os 
import cv2
import glob
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras.models import Model

# %% [markdown]
# ## Scenes Classification CONCATENATE Operator

# %%
# list đường dẫn các file ảnh
SCENES_CLASSIFICATION_PATH = 'scenes_classification'
train_path_imgs = list(glob.glob(SCENES_CLASSIFICATION_PATH+'/train/**/*.jpg'))
val_path_imgs = list(glob.glob(SCENES_CLASSIFICATION_PATH+'/val/**/*.jpg'))

# %%
# split đường dẫn các file để lấy label cho ảnh và tao thành dataframe để  thống kê
labels = list(map(lambda x:os.path.split(os.path.split(x)[0])[1], train_path_imgs))
file_path = pd.Series(train_path_imgs, name='File_Path').astype(str)
labels = pd.Series(labels, name='Labels')
data = pd.concat([file_path, labels], axis=1)
data = data.sample(frac=1).reset_index(drop=True)
data.head()
# Out:
#                                            File_Path   Labels
# 0  /home/aivn48/Desktop/DEL/Week25/2022/scenes_cl...   forest
# 1  /home/aivn48/Desktop/DEL/Week25/2022/scenes_cl...  glacier
# 2  /home/aivn48/Desktop/DEL/Week25/2022/scenes_cl...   forest
# 3  /home/aivn48/Desktop/DEL/Week25/2022/scenes_cl...  glacier
# 4  /home/aivn48/Desktop/DEL/Week25/2022/scenes_cl...   forest

# %%
# vẽ các ảnh tương ứng với label
fig, axes = plt.subplots(nrows=4, ncols=4, figsize=(10, 7),
                        subplot_kw={'xticks': [], 'yticks': []})
for i, ax in enumerate(axes.flat):
    ax.imshow(plt.imread(data.File_Path[i]))
    ax.set_title(data.Labels[i])
plt.tight_layout()
plt.show()

# %%
data.Labels.value_counts()
# Out:
# mountain     2512
# glacier      2404
# street       2382
# sea          2274
# forest       2271
# buildings    2191
# Name: Labels, dtype: int64

# %%
# Thống kê số lượng ảnh cho từng label 
counts = data.Labels.value_counts()
sns.barplot(x=counts.index, y=counts)
plt.xlabel('Labels')
plt.ylabel('Count')
plt.xticks(rotation=50);

# %%
batch_size = 32
img_height = 112
img_width = 112

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
  directory= os.path.join(SCENES_CLASSIFICATION_PATH, 'train'),
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 14034 files belonging to 6 classes.
# 2022-12-29 12:00:34.506763: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-29 12:00:34.523618: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-29 12:00:34.523691: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-29 12:00:34.524198: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-12-29 12:00:34.524643: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-29 12:00:34.524715: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-29 12:00:34.524758: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-29 12:00:34.790389: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-29 12:00:34.790489: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-29 12:00:34.790539: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-29 12:00:34.790592: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 46020 MB memory:  -> device: 0, name: NVIDIA RTX A6000, pci bus id: 0000:01:00.0, compute capability: 8.6

# %%
val_ds = tf.keras.utils.image_dataset_from_directory(
  directory=os.path.join(SCENES_CLASSIFICATION_PATH, 'val'),
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 3000 files belonging to 6 classes.

# %%
class_names = train_ds.class_names
print(class_names)
# Out:
# ['buildings', 'forest', 'glacier', 'mountain', 'sea', 'street']

# %%
plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.title(int(labels[i]))
        plt.axis("off")

# %%
data_augmentation = tf.keras.Sequential([
    layers.Rescaling(scale=1./255),
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.2),
    layers.RandomZoom(0.2),
    layers.RandomTranslation(height_factor=(-0.1, 0.1), width_factor=(-0.1, 0.1)
                                        , fill_mode='nearest'),
])

# %%
plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(data_augmentation(np.expand_dims(images[0].numpy(),axis=0).astype("uint8"))[0])
    plt.title(class_names[labels[0]])
    plt.axis("off")

# %% [markdown]
# ## ResNet34_V2 (skip connection: Concat)

# %%
class BuildResNet34_v2_Concat():
    def __init__(self):
        pass
    
    
    def identity_block(self, inputs, filters):
        x = layers.BatchNormalization()(inputs)
        x = layers.Activation('relu')(x)
        x = layers.Conv2D(filters=filters, kernel_size=(3,3), padding='same', use_bias=False)(x)
        
        x = layers.BatchNormalization()(x)
        x = layers.Activation('relu')(x)
        x = layers.Conv2D(filters=filters, kernel_size=(3,3), padding='same', use_bias=False)(x)
        

        x = layers.Concatenate(axis=-1)([inputs,x])
        
        ###################### Your Code Here ######################
        # Để thực hiện skip connection = concatenate, cần điều chỉnh số lượng channel  
        # sau khi concatenate về cùng số lượng channel thep yêu cầu đầu ra (filters). 
        
        '''
        (x) -> (BatchNorm)
        -> (ReLu)
        -> (Conv2D, 1x1, filters=filters, padding='same')
        '''
        
        ############################################################
        return x
        
    
    def projection_block(self, inputs, filters):
        x = layers.BatchNormalization()(inputs)
        x = layers.Activation('relu')(x)
        x = layers.Conv2D(filters=filters, kernel_size=(3,3), padding='same', strides=2, use_bias=False)(x)
        
        x = layers.BatchNormalization()(x)
        x = layers.Activation('relu')(x)
        x = layers.Conv2D(filters=filters, kernel_size=(3,3), padding='same', use_bias=False)(x)
        
        
        shortcut = layers.BatchNormalization()(inputs)
        shortcut = layers.Activation('relu')(shortcut)
        shortcut = layers.Conv2D(filters=filters, kernel_size=(1,1), padding='same', 
                                 strides=2, use_bias=False)(shortcut)
        
        x = layers.Concatenate(axis=-1)([shortcut,x])
        ###################### Your Code Here ######################
        # Để thực hiện skip connection = concatenate, cần điều chỉnh số lượng channel  
        # sau khi concatenate về cùng số lượng channel thep yêu cầu đầu ra (filters). 
        
        '''
        (x) -> (BatchNorm)
        -> (ReLu)
        -> (Conv2D, 1x1, filters=filters, padding='same')
        '''
        
        ############################################################
        
        return x
        
    def build_model(self, classes, method='add', input_shape=(224,224,3)):
        inputs = layers.Input(shape=input_shape)
        
        ###################### Your Code Here ######################
        #  Các bạn tham khảo Hình 2: Tham số trong kiến trúc ResNet34 (trong đề)
        # conv1 + max pool
        '''
        inputs -> (zero padding 3x3) 
        -> (Conv2D 7x7 stride=2, filter=64) 
        -> (zero padding 1x1) 
        -> (Max pooling 3x3, stride=2)
        '''
        
        # conv2_x
        '''
        (output from (Max pooling 3x3, stride=2)) -> (self.identity_block, filters=64) 
        -> (self.identity_block, filters=64)  
        -> (self.identity_block, filters=64) 
        '''
        
        
        # conv3_x
        '''
        (output from covn2_x) -> (self.projection_block, filters=128) 
        -> (self.identity_block, filters=128) 
        -> (self.identity_block, filters=128)  
        -> (self.identity_block, filters=128) 
        '''
        
        
        # conv4_x
        '''
        (output from covn3_x) -> (self.projection_block, filters=256) 
        -> (self.identity_block, filters=256) 
        -> (self.identity_block, filters=256)  
        -> (self.identity_block, filters=256) 
        -> (self.identity_block, filters=256) 
        -> (self.identity_block, filters=256) 
        '''
       
        
        # conv5_x
        '''
        (output from covn4_x) -> (self.projection_block, filters=512) 
        -> (self.identity_block, filters=512) 
        -> (self.identity_block, filters=512)
        '''
        
        
        '''
        (output from covn5_x) -> (BatchNorm)
        -> (ReLu)
        -> (GlobalAveragePooling2D)
        -> Dense, số lượng classes, softmax
        '''
        
        outputs = 
        ############################################################
        
        model = Model(inputs=inputs, outputs=outputs)
        
        return model

# %%
build_resnet34_v2_concat = BuildResNet34_v2_Concat()
resnet34_v2_model_concat = build_resnet34_v2_concat.build_model(input_shape=(img_height, img_width, 3), classes=6)

image_input = layers.Input(shape=(img_height,img_width,3))
x = data_augmentation(image_input)
x = resnet34_v2_model_concat(x)
scenes_classification_resnet34_v2_model_concat = Model(inputs=image_input, outputs=x)

scenes_classification_resnet34_v2_model_concat.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 112, 112, 3)]     0
#
#  sequential (Sequential)     (None, 112, 112, 3)       0
#
#  model (Functional)          (None, 6)                 23848134
#
# =================================================================
# Total params: 23,848,134
# Trainable params: 23,816,902
# Non-trainable params: 31,232
# _________________________________________________________________

# %%
num_epochs = 100

scenes_classification_resnet34_v2_model_concat.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
                      loss=tf.keras.losses.SparseCategoricalCrossentropy(), 
                      metrics=['accuracy'])


history = scenes_classification_resnet34_v2_model_concat.fit(train_ds,
                                epochs = num_epochs,
                                validation_data = val_ds)

# %%
plt.plot(history.history['loss'], label='loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.xlabel('Epoch')
plt.ylabel('Error scenes_classification_resnet34_v2_model_concat')
plt.legend()
plt.grid(True)

# %%
plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label='val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy scenes_classification_resnet34_v2_model_concat')
plt.legend()
plt.grid(True)

# %%
hist = pd.DataFrame(history.history)
hist['epoch'] = history.epoch
hist.tail()
